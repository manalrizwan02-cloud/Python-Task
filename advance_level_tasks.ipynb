# %% [markdown]
# <a href="https://colab.research.google.com/github/manalrizwan02-cloud/Python-Task/blob/main/advance_level_tasks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Total_expense=int(input("Enter your Total Expenses:"))

daily_expenses=[]

for i in range(1,Total_expense+1):
     expense_name=input("Enter your Expense Name:")
     category_name=input("Enter your Expense Category Name:").title()
     amount=int(input("Enter your Expense Amount:"))

     expense={
       "Name":expense_name,
       "Category":category_name,
       "Amount":amount
     }

     daily_expenses.append(expense)
print("Daily Expenses :", daily_expenses)

total_spending=0
for expense in daily_expenses:
    total_spending+=expense["Amount"]


Highest_expense=0

for expense in daily_expenses:
    print(expense["Category"],":",expense["Amount"])

    if expense["Amount"] > Highest_expense:
         Highest_expense= expense["Amount"]

category_spending = {
    "Food": 0,
    "Transport": 0,
    "Shopping":0,
    "Bill":0
}
for expense in daily_expenses:
    category = expense["Category"]
    amount = expense["Amount"]
    category_spending[category] += amount

budget=float(input("Enter your Budget:"))

if total_spending > budget:
    Budget_Status="Warning Budget Exceeded!"
else:
   Budget_Status= "You're in your Budget"

def final_report():
    print("\n====== Total Expense Report======")
    print("Total_spending:",total_spending)
    print("Category Spending:")
    for category, amount in category_spending.items():
        print(category,":",amount)
    print("Highest Expense:",Highest_expense)
    print("Budget Status:",Budget_Status)
    return
final_report()

# %%
# Store Inventory System

products_list = []


# 1. Add Product
def Add_Product():
    name = input("Enter Product Name: ")
    price = int(input("Enter Product Price: "))
    quantity = int(input("Enter Available Quantity: "))

    product = {
        "name": name,
        "price": price,
        "quantity": quantity
    }

    products_list.append(product)

    print("Product added successfully.")


# 2. Sell Product
def Sell_Product():
    name = input("Enter Product Name: ")

    for product in products_list:

        if name == product["name"]:
            print("Product Found!")

            quantity = int(input("Enter Quantity to Sell: "))

            if quantity <= product["quantity"]:
                product["quantity"] -= quantity
                print("Product sold successfully.")
            else:
                print("Insufficient Quantity.")

            break

    else:
        print("Product not found.")


# 3. Restock Product
def Restock_Product():
    name = input("Enter Product Name: ")

    for product in products_list:

        if name == product["name"]:
            print("Product Found!")

            quantity = int(input("Enter Quantity to Restock: "))

            product["quantity"] += quantity

            print("Product restocked successfully.")

            break

    else:
        print("Product not found.")


# 4. Search Product
def Search_Product():
    name = input("Enter Product Name: ")

    for product in products_list:

        if name == product["name"]:
            print("Product Found!")
            print("Price:", product["price"])
            print("Quantity:", product["quantity"])

            break

    else:
        print("Product not found.")


# 5. Display Inventory
def Display_Inventory():

    total_value = 0

    print("\n===== Inventory =====")

    for product in products_list:

        print("\nProduct Name:", product["name"])
        print("Price:", product["price"])
        print("Quantity:", product["quantity"])

        product_value = product["price"] * product["quantity"]

        print("Product Value:", product_value)

        total_value += product_value

        if product["quantity"] < 5:
            print("Low Stock!")

    print("\nTotal Inventory Value:", total_value)


# Main Menu
while True:

    print("\n===== Store Inventory Menu =====")
    print("1. Add Product")
    print("2. Sell Product")
    print("3. Restock Product")
    print("4. Search Product")
    print("5. Display Inventory")
    print("6. Exit")

    choice = input("Enter your choice: ")

    if choice == "1":
        Add_Product()

    elif choice == "2":
        Sell_Product()

    elif choice == "3":
        Restock_Product()

    elif choice == "4":
        Search_Product()

    elif choice == "5":
        Display_Inventory()

    elif choice == "6":
        print("Program ended.")
        break

    else:
        print("Invalid choice.")
# Out:
# ===== Store Inventory Menu =====
# 1. Add Product
# 2. Sell Product
# 3. Restock Product
# 4. Search Product
# 5. Display Inventory
# 6. Exit
# Enter your choice: 1
# Enter Product Name: pen
# Enter Product Price: 30
# Enter Available Quantity: 50
# Product added successfully.
#
# ===== Store Inventory Menu =====
# 1. Add Product
# 2. Sell Product
# 3. Restock Product
# 4. Search Product
# 5. Display Inventory
# 6. Exit
# Enter your choice: 1
# Enter Product Name: juice
# Enter Product Price: 50
# Enter Available Quantity: 60
# Product added successfully.
#
# ===== Store Inventory Menu =====
# 1. Add Product
# 2. Sell Product
# 3. Restock Product
# 4. Search Product
# 5. Display Inventory
# 6. Exit
# Enter your choice: 2
# Enter Product Name: juice
# Product Found!
# Enter Quantity to Sell: 30
# Product sold successfully.
#
# ===== Store Inventory Menu =====
# 1. Add Product
# 2. Sell Product
# 3. Restock Product
# 4. Search Product
# 5. Display Inventory
# 6. Exit
# ...

# %%
#task 13: Clinic Appointment Manager
patient_list = []

total_patient = int(input("Enter total patients: "))

for i in range(1, total_patient + 1):

    patient_id =int(input("Enter Patient ID: "))

    for patient in patient_list:
        if patient["Patient ID"] == patient_id:
            print("Patient ID already exists")
            break
    else:
        patient_name = input("Enter Patient Name: ")
        age = int(input("Enter Age: "))
        disease = input("Enter Disease/Problem: ")
        appointment_time = input("Enter Appointment Time: ")
        emergency = input("Emergency? (Yes/No): ")

        patient = {
            "Patient ID": patient_id,
            "Patient Name": patient_name,
            "Age": age,
            "Disease": disease,
            "Appointment Time": appointment_time,
            "Emergency": emergency
        }

        patient_list.append(patient)

    print("\n",patient_list)


def Add_Appoinment():


        patient_id = int(input("Enter the Patient's Appoinment:"))
        patient_name = input("Enter Patient Name: ")
        age = int(input("Enter Age: "))
        disease = input("Enter Disease/Problem: ")
        appointment_time = input("Enter Appointment Time: ")
        emergency = input("Emergency? (Yes/No): ")

        patient = {
            "Patient ID": patient_id,
            "Patient Name": patient_name,
            "Age": age,
            "Disease": disease,
            "Appointment Time": appointment_time,
            "Emergency": emergency
        }
        patient_list.append(patient)
        print(patient_list)

Add_Appoinment()


def Search_Patient():
    search_patient =int(input("Enter the Patient's ID to search:"))

    for patient in patient_list:
        if search_patient == patient["Patient ID"]:
             print("Patient found")
             print("\nPatient Name:", patient_name)
             print("Patient Age:",age)
             print("Patient Disease:",disease)
             print("Patient Appoinmrnt Time:",appointment_time)
             print("Emergency Status:",emergency)
             break
    else:
        print("Patient not found")

Search_Patient()

def Display_Appoinments():
    for patient in patient_list:
        if patient["Emergency"] =="Yes":

            print("\n--------Emergency patient--------")
            print("\n Patient ID:",patient["Patient ID"])
            print("Patient Name:", patient["Patient Name"])
            print("Patient Age:",patient["Age"])
            print("Patient Disease:",patient["Disease"])
            print("Patient Appoinmrnt Time:",patient["Appointment Time"])
            print("Emergency Status:",patient["Emergency"])
            print("----------------")


    for patient in patient_list:
        if  patient["Emergency"] == "No":

            print("\n--------Normal patient--------")
            print("\n Patient ID:",patient["Patient ID"])
            print("Patient Name:", patient["Patient Name"])
            print("Patient Age:",patient["Age"])
            print("Patient Disease:",patient["Disease"])
            print("Patient Appoinmrnt Time:",patient["Appointment Time"])
            print("Emergency Status:",patient["Emergency"])
            print("----------------")

Display_Appoinments()

def  Cancel_Appoinment():
    patient_id = int(input("Enter the Patient ID to Cancel the appoinment:"))

    for patient in patient_list:
        if patient_id ==patient["Patient ID"]
            print("\nPatient Found to Cancel Appoinment")
            patient_list.remove(patient)
            print("\nPatient appoinment cancelled successfully")
            break

    print(patient_list)

Cancel_Appoinment()
# Out:
# Enter total patients: 2
# Enter Patient ID: 11
# Enter Patient Name: ali
# Enter Age: 3
# Enter Disease/Problem: fever
# Enter Appointment Time: 6
# Emergency? (Yes/No): No
#
#  [{'Patient ID': 11, 'Patient Name': 'ali', 'Age': 3, 'Disease': 'fever', 'Appointment Time': '6', 'Emergency': 'No'}]
# Enter Patient ID: 12
# Enter Patient Name: fozia
# Enter Age: 13
# Enter Disease/Problem: jaundice
# Enter Appointment Time: 7
# Emergency? (Yes/No): Yes
#
#  [{'Patient ID': 11, 'Patient Name': 'ali', 'Age': 3, 'Disease': 'fever', 'Appointment Time': '6', 'Emergency': 'No'}, {'Patient ID': 12, 'Patient Name': 'fozia', 'Age': 13, 'Disease': 'jaundice', 'Appointment Time': '7', 'Emergency': 'Yes'}]
# Enter the Patient's Appoinment:13
# Enter Patient Name: laila
# Enter Age: 9
# Enter Disease/Problem: flo
# Enter Appointment Time: 3
# Emergency? (Yes/No): No
# ...

# %%
#task 13: Clinic Appointment Manager
patient_list = []

total_patient = int(input("Enter total patients: "))

for i in range(1, total_patient + 1):

    patient_id = int(input("Enter Patient ID: "))

    for patient in patient_list:
        if patient["Patient ID"] == patient_id:
            print("Patient ID already exists")
            break
    else:
        patient_name = input("Enter Patient Name: ")
        age = int(input("Enter Age: "))
        disease = input("Enter Disease/Problem: ")
        appointment_time = input("Enter Appointment Time: ")
        emergency = input("Emergency? (Yes/No): ")

        patient = {
            "Patient ID": patient_id,
            "Patient Name": patient_name,
            "Age": age,
            "Disease": disease,
            "Appointment Time": appointment_time,
            "Emergency": emergency
        }

        patient_list.append(patient)

    print("\n",patient_list)


def Add_Appoinment():


        patient_id =int(input("Enter the Patient's ID Appoinment:"))
        patient_name = input("Enter Patient Name: ")
        age = int(input("Enter Age: "))
        disease = input("Enter Disease/Problem: ")
        appointment_time = input("Enter Appointment Time: ")
        emergency = input("Emergency? (Yes/No): ")

        patient = {
            "Patient ID": patient_id,
            "Patient Name": patient_name,
            "Age": age,
            "Disease": disease,
            "Appointment Time": appointment_time,
            "Emergency": emergency
        }
        patient_list.append(patient)
        print(patient_list)




def Search_Patient():
    search_patient =int(input("Enter the Patient's ID to search:"))

    for patient in patient_list:
        if search_patient == patient["Patient ID"]:
             print("Patient found")
             print("\nPatient Name:", patient_name)
             print("Patient Age:",age)
             print("Patient Disease:",disease)
             print("Patient Appoinmrnt Time:",appointment_time)
             print("Emergency Status:",emergency)
             break
    else:
        print("Patient not found")



def Display_Appoinments():
    for patient in patient_list:
        if patient["Emergency"] =="Yes":

            print("\n--------Emergency patient--------")
            print("\n Patient ID:",patient["Patient ID"])
            print("Patient Name:", patient["Patient Name"])
            print("Patient Age:",patient["Age"])
            print("Patient Disease:",patient["Disease"])
            print("Patient Appoinmrnt Time:",patient["Appointment Time"])
            print("Emergency Status:",patient["Emergency"])
            print("----------------")


    for patient in patient_list:
        if  patient["Emergency"] == "No":

            print("\n--------Normal patient--------")
            print("\n Patient ID:",patient["Patient ID"])
            print("Patient Name:", patient["Patient Name"])
            print("Patient Age:",patient["Age"])
            print("Patient Disease:",patient["Disease"])
            print("Patient Appoinmrnt Time:",patient["Appointment Time"])
            print("Emergency Status:",patient["Emergency"])
            print("----------------")


def  Cancel_Appoinment():
    patient_id = int(input("Enter the Patient ID to Cancel the appoinment:"))

    for patient in patient_list:

        if patient_id == patient["Patient ID"]:
            print("patient Found")
            patient_list.remove(patient)
            print("Patient Appoinment Cancelled Successfully")
            break

    print(patient_list)



def Clinic_Summary():
    print("\n--------Clinic Summary--------")
    print("Total Patients:",total_patient)

    emergency_count =0
    normal_count =0
    for patient in patient_list:
        if patient["Emergency"] =="Yes":
            emergency_count +=1

        elif patient["Emergency"] =="No":
            normal_count +=1
            break
    print("Total Patients:",len(patient_list))
    print("Total Emergency Patient:",emergency_count)
    print("Total Normal Patient:",normal_count)




while True:

    print("\n-------- Clinic Appointment Manager --------")
    print("1. Add Appointment")
    print("2. Search Patient")
    print("3. Display Appointments")
    print("4. Cancel Appointment")
    print("5. Display Clinic Summary")
    print("6. Exit")

    choice = int(input("Enter your choice: "))

    if choice == 1:
        Add_Appoinment()

    elif choice == 2:
        Search_Patient()

    elif choice == 3:
        Display_Appoinments()

    elif choice == 4:
        Cancel_Appoinment()

    elif choice == 5:
        Clinic_Summary()

    elif choice == 6:
        print("Thank you!")
        break

    else:
        print("Invalid choice")
# Out:
#  [{'Patient ID': 3, 'Patient Name': 'Ali', 'Age': 5, 'Disease': 'Fever', 'Appointment Time': '6', 'Emergency': 'No'}]
#
#  [{'Patient ID': 3, 'Patient Name': 'Ali', 'Age': 5, 'Disease': 'Fever', 'Appointment Time': '6', 'Emergency': 'No'}, {'Patient ID': 12, 'Patient Name': 'Fozia', 'Age': 3, 'Disease': 'Jaundice', 'Appointment Time': '7', 'Emergency': 'Yes'}]
#
#  [{'Patient ID': 3, 'Patient Name': 'Ali', 'Age': 5, 'Disease': 'Fever', 'Appointment Time': '6', 'Emergency': 'No'}, {'Patient ID': 12, 'Patient Name': 'Fozia', 'Age': 3, 'Disease': 'Jaundice', 'Appointment Time': '7', 'Emergency': 'Yes'}, {'Patient ID': 13, 'Patient Name': 'Laila', 'Age': 4, 'Disease': 'Typhoid', 'Appointment Time': '8', 'Emergency': 'Yes'}]
#
# -------- Clinic Appointment Manager --------
# 1. Add Appointment
# 2. Search Patient
# 3. Display Appointments
# 4. Cancel Appointment
# 5. Display Clinic Summary
# 6. Exit
# ...
