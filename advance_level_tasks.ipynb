# %% [markdown]
# <a href="https://colab.research.google.com/github/manalrizwan02-cloud/Python-Task/blob/Python-Beginner-task/advance_level_tasks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Total_expense=int(input("Enter your Total Expenses:"))

daily_expenses=[]

for i in range(1,Total_expense+1):
     expense_name=input("Enter your Expense Name:")
     category_name=input("Enter your Expense Category Name:").title()
     amount=int(input("Enter your Expense Amount:"))

     expense={
       "Name":expense_name,
       "Category":category_name,
       "Amount":amount
     }

     daily_expenses.append(expense)
print("Daily Expenses :", daily_expenses)

total_spending=0
for expense in daily_expenses:
    total_spending+=expense["Amount"]


Highest_expense=0

for expense in daily_expenses:
    print(expense["Category"],":",expense["Amount"])

    if expense["Amount"] > Highest_expense:
         Highest_expense= expense["Amount"]

category_spending = {
    "Food": 0,
    "Transport": 0,
    "Shopping":0,
    "Bill":0
}
for expense in daily_expenses:
    category = expense["Category"]
    amount = expense["Amount"]
    category_spending[category] += amount

budget=float(input("Enter your Budget:"))

if total_spending > budget:
    Budget_Status="Warning Budget Exceeded!"
else:
   Budget_Status= "You're in your Budget"

def final_report():
    print("\n====== Total Expense Report======")
    print("Total_spending:",total_spending)
    print("Category Spending:")
    for category, amount in category_spending.items():
        print(category,":",amount)
    print("Highest Expense:",Highest_expense)
    print("Budget Status:",Budget_Status)
    return
final_report()

# %%
# Store Inventory Management System

products = {
    "Pen": {
        "price": 50,
        "quantity": 10
    },
    "Notebook": {
        "price": 200,
        "quantity": 4
    },
    "Bag": {
        "price": 1500,
        "quantity": 7
    }
}


def Add_Product():
    name = input("Enter Product Name: ")
    price = int(input("Enter Product Price: "))
    quantity = int(input("Enter Available Quantity: "))

    products[name] = {
        "price": price,
        "quantity": quantity
    }

    print("Product added successfully.")


def Sell_Product():
    name = input("Enter Product Name: ")

    if name in products:
        quantity = int(input("Enter Quantity to Sell: "))

        if quantity <= products[name]["quantity"]:
            products[name]["quantity"] -= quantity
            print("Product sold successfully.")
        else:
            print("Insufficient stock!")

    else:
        print("Product not found.")


def Restock_Product():
    name = input("Enter Product Name: ")

    if name in products:
        quantity = int(input("Enter Quantity to Restock: "))
        products[name]["quantity"] += quantity

        print("Product restocked successfully.")

    else:
        print("Product not found.")


def Search_Product():
    name = input("Enter Product Name: ")

    if name in products:
        print("Product Found!")
        print("Price:", products[name]["price"])
        print("Quantity:", products[name]["quantity"])

    else:
        print("Product not found.")


def Display_Inventory():
    total_value = 0

    print("\n===== Inventory =====")

    for name in products:
        print("\nProduct Name:", name)
        print("Price:", products[name]["price"])
        print("Quantity:", products[name]["quantity"])

        product_value = products[name]["price"] * products[name]["quantity"]

        print("Product Value:", product_value)

        total_value += product_value

        if products[name]["quantity"] < 5:
            print("Low Stock!")


    print("\nTotal Inventory Value:", total_value)


while True:

    print("\n===== Store Inventory Menu =====")
    print("1. Add Product")
    print("2. Sell Product")
    print("3. Restock Product")
    print("4. Search Product")
    print("5. Display Inventory")
    print("6. Exit")

    choice = input("Enter your choice: ")

    if choice == "1":
        Add_Product()

    elif choice == "2":
        Sell_Product()

    elif choice == "3":
        Restock_Product()

    elif choice == "4":
        Search_Product()

    elif choice == "5":
        Display_Inventory()

    elif choice == "6":
        print("Program ended.")
        break

    else:
        print("Invalid choice.")
# Out:
# ===== Store Inventory Menu =====
# 1. Add Product
# 2. Sell Product
# 3. Restock Product
# 4. Search Product
# 5. Display Inventory
# 6. Exit
# Enter your choice: 1
# Enter Product Name: Pencil
# Enter Product Price: 30
# Enter Available Quantity: 4
# Product added successfully.
#
# ===== Store Inventory Menu =====
# 1. Add Product
# 2. Sell Product
# 3. Restock Product
# 4. Search Product
# 5. Display Inventory
# 6. Exit
# Enter your choice: 1
# Enter Product Name: Eraser
# Enter Product Price: 15
# Enter Available Quantity: 6
# Product added successfully.
#
# ===== Store Inventory Menu =====
# 1. Add Product
# 2. Sell Product
# 3. Restock Product
# 4. Search Product
# 5. Display Inventory
# 6. Exit
# Enter your choice: 2
# Enter Product Name: Pen
# Enter Quantity to Sell: 4
# Product sold successfully.
#
# ===== Store Inventory Menu =====
# 1. Add Product
# 2. Sell Product
# 3. Restock Product
# 4. Search Product
# 5. Display Inventory
# 6. Exit
# Enter your choice: 3
# ...

# %%
#Task 13:Library Book Management System

books =[]
for i in books:
  id = int(input("Enter the Book ID:"))
  title = input("Enter the Book Title:")
  author = input("Enter the Author name of book:")
  availability_status = input("Enter the Availability Status: Yes/No")

  books = {
      "id":id,
      "title":title,
      "author":author,
      "availability_status"
  }
# Out:
#   File "/tmp/ipykernel_1420/1492016747.py", line 14
#     "availability_status"
#                         ^
# SyntaxError: ':' expected after dictionary key

# %%
from ast import Break
#Task 13:Library Book Management System

book_list =[]
while True:

  id = int(input("Enter the Book ID:"))
  title = input("Enter the Book Title:")
  author = input("Enter the Author name of book:")
  availability_status = input("Enter the Availability Status Yes/No :")

  book = {
      "id":id,
      "title":title,
      "author":author,
      "availability_status":availability_status
  }
  book_list.append(book)


  add_more = input("\nDo you want more books Yes/No :")
  if add_more == "No":
      break
print("BOOK LIST:",book_list)

print("\n------ Library Books ------")

for book in book_list:

    for keys, values in book.items():
        print("\n",keys, ":", values)

def Add_Book():
  id = int(input("Enter the Book ID:"))
  title = input("Enter the Book Title:")
  author = input("Enter the Author name of book:")
  availability_status = input("Enter the Availability Status Yes/No :")

  book = {
      "id":id,
      "title":title,
      "author":author,
      "availability_status":availability_status
  }
  book_list.append(book)


def display_Books():
 print("-----Library Book List-----")
 for book in book_list:
     for keys, values in book.items():
      print("\n",keys, ":", values)

def Search_Book():
  search_book = input("Enter the Book Title to Search:")

  for book in book_list:
    if search_book == book["title"]:
      print("Book found")

      print("Book ID:", book["id"])
      print("Book Title:",book["title"])
      print("Avalability Status:",book["availability_status"])





def Borrow_Book():
  borrow_book = input("Enter the Book title to Borrow:")
  for book in book_list:
    if borrow_book == book["title"]:

       if book["availability_status"] == "Yes":
        book["availability_status"] = "No"
       else:
        print("Book is not Available")



def Return_Book():
  return_book = input("Enter the Book to Return:")
  for book in book_list:
    if return_book == book["title"]:

      if book["Availability_status"] == "No":
        book["Availability_status"] = "Yes"
        print("Borrow book successfully")
      else:
        print("Book is already Available")



while True:

 print("\n------ Library Menu ------")
 print("1. Add Book")
 print("2. Display Books")
 print("3. Search Book")
 print("4. Borrow Book")
 print("5. Return Book")
 print("6. Exit")

 choice = input("Enter the choice:")

 if choice == "1":
  Add_Book()

 elif choice == "2":
  display_Books()

 elif choice == "3":
  Search_Book()

 elif choice == "4":
  Borrow_Book()

 elif choice == "5":
  Return_Book()

 elif choice == "6":
  print("Good Bye")
  break
# Out:
# BOOK LIST: [{'id': 123, 'title': 'python', 'author': 'guido', 'availability_status': 'Yes'}]
#
# ------ Library Books ------
#
#  id : 123
#
#  title : python
#
#  author : guido
#
#  availability_status : Yes
#
# ------ Library Menu ------
# 1. Add Book
# 2. Display Books
# 3. Search Book
# 4. Borrow Book
# 5. Return Book
# 6. Exit
#
# ------ Library Menu ------
# 1. Add Book
# 2. Display Books
# 3. Search Book
# 4. Borrow Book
# 5. Return Book
# 6. Exit
# -----Library Book List-----
#
#  id : 123
#
#  title : python
#
#  author : guido
#
#  availability_status : Yes
#
#  id : 567
#
#  title : ai
#
#  author : john
#
#  availability_status : Yes
#
# ------ Library Menu ------
# 1. Add Book
# 2. Display Books
# 3. Search Book
# 4. Borrow Book
# 5. Return Book
# 6. Exit
# Book found
# Book ID: 567
# Book Title: ai
# Avalability Status: Yes
#
# ------ Library Menu ------
# 1. Add Book
# 2. Display Books
# 3. Search Book
# 4. Borrow Book
# 5. Return Book
# 6. Exit
#
# ...
